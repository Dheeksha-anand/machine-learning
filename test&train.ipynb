# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/dataset/test.csv")
df
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['x'],df['y'])

# %%
x=df[['x']]
x
# Out:
#       x
# 0    77
# 1    21
# 2    22
# 3    20
# 4    36
# ..   ..
# 295  71
# 296  46
# 297  55
# 298  62
# 299  47
#
# [300 rows x 1 columns]

# %%
y=df['y']
y
# Out:
# 0      79.775152
# 1      23.177279
# 2      25.609262
# 3      17.857388
# 4      41.849864
#          ...
# 295    68.545888
# 296    47.334876
# 297    54.090637
# 298    63.297171
# 299    52.459467
# Name: y, Length: 300, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(x_train)
# Out:
# 240

# %%
len(x_test)
# Out:
# 60

# %%
from sklearn.linear_model import LinearRegression
ans=LinearRegression()

# %%
ans.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ans.predict(x_test)
# Out:
# array([ 27.0619666 ,  74.57712065,  53.34694543,   6.84275211,
#         23.0181237 ,  20.99620225,  10.88659501,  91.76345296,
#         76.59904209,  36.16061312,  15.94139863,  96.81825658,
#         37.17157384,  98.84017803,  59.41270978,  49.30310253,
#          7.85371283,  15.94139863,  59.41270978,  61.43463123,
#         60.4236705 ,  90.75249224,  91.76345296,  -0.23397296,
#         79.63192427,  69.52231702,  37.17157384,  89.74153151,
#         93.78537441,  42.22637746,   8.86467356,  18.9742808 ,
#         97.82921731,  94.79633513,  47.28118109,  35.14965239,
#         66.48943485, 100.86209948,  44.24829891,  11.89755573,
#         63.45655268,  62.44559195,  41.21541674,  23.0181237 ,
#         95.80729586,  60.4236705 ,  88.73057079,  89.74153151,
#         46.27022036,  61.43463123,  15.94139863,  26.05100587,
#         78.62096354,  18.9742808 ,  27.0619666 ,  67.50039557,
#         64.4675134 ,  95.80729586,  12.90851645,  87.71961006])

# %%
y_test
# Out:
# 23      21.713803
# 103     75.692986
# 73      50.170086
# 159     10.414681
# 214     23.526472
# 168     18.983223
# 291      8.673336
# 93      89.123775
# 266     79.503415
# 259     38.677808
# 111     16.687152
# 224     96.119825
# 230     40.007096
# 122     95.580172
# 54      59.612471
# 164     52.286206
# 271      9.391417
# 260     16.828397
# 212     62.226357
# 194     60.071375
# 253     60.111350
# 248     89.899991
# 40      95.061409
# 119     -3.467884
# 72      77.910330
# 37      69.463061
# 45      36.113348
# 256     92.402177
# 182     99.435779
# 287     41.469239
# 143     10.804627
# 285     14.995143
# 113     97.703422
# 112     96.588886
# 125     46.690140
# 49      34.311414
# 167     67.220080
# 87     105.591837
# 213     45.963969
# 123      7.468502
# 154     61.740632
# 6       58.874659
# 66      38.688887
# 210     24.683627
# 217     95.797473
# 150     59.831397
# 51      87.847499
# 108     87.457216
# 70      46.561418
# 63      59.225745
# 237     11.217105
# 201     25.756125
# 200     78.396830
# 11      17.095372
# 29      26.591124
# 208     68.488207
# 138     64.375211
# 251     90.714817
# 71      10.347545
# 18      90.655137
# Name: y, dtype: float64

# %%
ans.score(x_train,y_train)
# Out:
# 0.987728577407871

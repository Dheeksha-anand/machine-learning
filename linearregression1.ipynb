# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("/content/drive/MyDrive/dataset/linear.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# @title area vs price

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='area', y='price', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b54fd9d04d69> in <cell line: 4>()
#       2
#       3 from matplotlib import pyplot as plt
# ----> 4 df.plot(kind='scatter', x='area', y='price', s=32, alpha=.8)
#       5 plt.gca().spines[['top', 'right',]].set_visible(False)
#       6 plt.plot(df.area,reg.predict(df[['area']]),color='blue')
#
# NameError: name 'df' is not defined

# %% [markdown]
# # New Section

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']], df['price'])

# Predict the price for an area of 3300 sq ft
reg.predict(pd.DataFrame({'area': [1000]}))
# Out:
# array([316404.10958904])

# %% [markdown]
# X = df[['area']]  # Features should be a DataFrame
# y = df['price']
#
# # Create and train the model
# reg = LinearRegression()
# reg.fit(X, y)
#
# # Predict the price for an area of 3300
# prediction = reg.predict(pd.DataFrame({'area': [3300]}))
# print(f'Predicted price for 3300 sq ft: ${prediction[0]:.2f}')

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*4300+180616.43835616432
# Out:
# 764503.4246451643

# %%
d=pd.read_csv("/content/drive/MyDrive/dataset/areas.csv")
d
# Out:
#    areas
# 0   1000
# 1   2000
# 2   3000
# 3   4000
# 4   5000

# %%
# Print column names to diagnose the issue (optional)
print("New data columns:", d.columns)

# Ensure the column name matches the one used in training
if 'areas' in d.columns:
    d.rename(columns={'areas': 'area'}, inplace=True)

# Ensure the new data has the correct column name
if 'area' not in d.columns:
    raise KeyError("Missing 'area' column in the new data")

# Prepare new data for prediction
areas_to_predict = d[['area']]  # Ensure it's a DataFrame

# Predict prices using the trained model
predictions = reg.predict(areas_to_predict)

# Add predictions to the DataFrame
d['predicted_price'] = predictions

# Save the results to a new CSV file
d.to_csv("/predicted_prices.csv", index=False)

# Display the DataFrame with predictions
print(d.head())
# Out:
# New data columns: Index(['areas'], dtype='object')
#    area  predicted_price
# 0  1000    316404.109589
# 1  2000    452191.780822
# 2  3000    587979.452055
# 3  4000    723767.123288
# 4  5000    859554.794521

# %%
d.to_csv("/content/drive/MyDrive/dataset/prediction.csv")
